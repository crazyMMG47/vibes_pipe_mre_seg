# %% [markdown]
# # Overall dataset spilt

# %% [markdown]
# Since we have 135 total and have 27 untouched test subjects.
#
# train: 81
# val: 27
# test: 27
#
# Val and test are fixed from the beginning. Val monitors iteration improvement, true weights, choosing stopping counts. Test are for final comparison only.

# %% [markdown]
# ## Stage 1: feasibility/tuning
#
# train on all 24 data and get their pseudo-gt
# fixed training-set label refinment
# 6 predictions each
# 144 NLI solves
#
# pros of doing fixed training-set label refinement:
# - clean scientifically
# - isolates the effect of the feedback mechanism
# - no leakage into test
#
# cons:
# - risk of confirmation bias
# - less label diversity than adding new subjects

# %% [markdown]
# ## Stage 2: Selective refinement within fixed 87-train split
#
# discuss this with Grace further.
